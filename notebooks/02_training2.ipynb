# %%
# Import data handling libraries
import pandas as pd
import numpy as np

# Import text cleaning support
import re

# Import plotting libraries for quick checks if needed
import matplotlib.pyplot as plt
import seaborn as sns

# Import TF IDF vectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# Import baseline text classification models
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB

# Import evaluation metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# Import model saving utility
import joblib

# %%
# Load sampled training data from csv
df_train = pd.read_csv(r"..\data\processed\cfpb_sample_500k.csv")

# %%
# Check dataset shape
df_train.shape
# Out:
# (500000, 4)

# %%
# Preview the first rows
df_train.head()
# Out:
#                                                 text            target  \
# 0  Hi I am submitting this XXXX XXXX this isn't a...  Credit reporting
# 1  A federal education loan was fraudulently open...   Debt collection
# 2  I am writing to have the following information...  Credit reporting
# 3  I want this late payment remove from my accoun...       Credit card
# 4  I am disputing several items on my Experian cr...  Credit reporting
#
#                                           text_clean    target_grouped
# 0  hi i am submitting this xxxx xxxx this isn t a...  Credit reporting
# 1  a federal education loan was fraudulently open...   Debt collection
# 2  i am writing to have the following information...  Credit reporting
# 3  i want this late payment remove from my accoun...       Credit card
# 4  i am disputing several items on my experian cr...  Credit reporting

# %% [markdown]
# #### Bert

# %%
# Install transformer libraries for BERT fine tuning
# !pip install transformers datasets accelerate
# Out:
# Requirement already satisfied: transformers in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (5.5.0)
# Requirement already satisfied: datasets in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (4.8.4)
# Requirement already satisfied: accelerate in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (1.13.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from transformers) (4.67.3)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from transformers) (2026.3.32)
# Requirement already satisfied: packaging>=20.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from transformers) (26.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from transformers) (1.8.0)
# Requirement already satisfied: typer in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from transformers) (0.24.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from transformers) (2.2.6)
# Requirement already satisfied: pandas in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from datasets) (2.3.3)
# Requirement already satisfied: xxhash in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from datasets) (0.4.1)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from datasets) (23.0.1)
# Requirement already satisfied: httpx<1.0.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: filelock in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from datasets) (3.25.2)
# Requirement already satisfied: multiprocess<0.70.20 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from datasets) (0.70.19)
# Requirement already satisfied: requests>=2.32.2 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from datasets) (2.33.0)
# Requirement already satisfied: fsspec[http]<=2026.2.0,>=2023.1.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from datasets) (2026.2.0)
# Requirement already satisfied: torch>=2.0.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from accelerate) (2.11.0)
# Requirement already satisfied: psutil in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from accelerate) (7.2.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.5)
# Requirement already satisfied: idna in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: httpcore==1.* in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: certifi in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from httpx<1.0.0->datasets) (2026.2.25)
# Requirement already satisfied: anyio in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from httpx<1.0.0->datasets) (4.13.0)
# Requirement already satisfied: h11>=0.16 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.4.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from requests>=2.32.2->datasets) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from requests>=2.32.2->datasets) (2.6.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: setuptools<82 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from torch>=2.0.0->accelerate) (65.5.0)
# Requirement already satisfied: jinja2 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: colorama in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from pandas->datasets) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: click>=8.2.1 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from typer->transformers) (8.3.1)
# Requirement already satisfied: rich>=12.3.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from typer->transformers) (14.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (5.0.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.23.0)
# Requirement already satisfied: six>=1.5 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from rich>=12.3.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Install the required packages in the notebook environment
# !pip install -U "accelerate>=1.1.0" transformers datasets
# Out:
# Requirement already satisfied: accelerate>=1.1.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (1.13.0)
# Requirement already satisfied: transformers in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (5.5.0)
# Requirement already satisfied: datasets in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (4.8.4)
# Requirement already satisfied: huggingface_hub>=0.21.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from accelerate>=1.1.0) (1.8.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from accelerate>=1.1.0) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from accelerate>=1.1.0) (26.0)
# Requirement already satisfied: torch>=2.0.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from accelerate>=1.1.0) (2.11.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from accelerate>=1.1.0) (0.7.0)
# Requirement already satisfied: psutil in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from accelerate>=1.1.0) (7.2.2)
# Requirement already satisfied: pyyaml in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from accelerate>=1.1.0) (6.0.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from transformers) (0.24.1)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from transformers) (2026.3.32)
# Requirement already satisfied: tqdm>=4.27 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from transformers) (4.67.3)
# Requirement already satisfied: httpx<1.0.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: fsspec[http]<=2026.2.0,>=2023.1.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from datasets) (2026.2.0)
# Requirement already satisfied: filelock in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from datasets) (3.25.2)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from datasets) (0.4.1)
# Requirement already satisfied: xxhash in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from datasets) (0.70.19)
# Requirement already satisfied: pandas in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from datasets) (2.33.0)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from datasets) (23.0.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.5)
# Requirement already satisfied: httpcore==1.* in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: anyio in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from httpx<1.0.0->datasets) (4.13.0)
# Requirement already satisfied: idna in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: certifi in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from httpx<1.0.0->datasets) (2026.2.25)
# Requirement already satisfied: h11>=0.16 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from huggingface_hub>=0.21.0->accelerate>=1.1.0) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from huggingface_hub>=0.21.0->accelerate>=1.1.0) (1.4.3)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from requests>=2.32.2->datasets) (2.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from requests>=2.32.2->datasets) (3.4.6)
# Requirement already satisfied: jinja2 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from torch>=2.0.0->accelerate>=1.1.0) (3.1.6)
# Requirement already satisfied: setuptools<82 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from torch>=2.0.0->accelerate>=1.1.0) (65.5.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from torch>=2.0.0->accelerate>=1.1.0) (3.4.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from torch>=2.0.0->accelerate>=1.1.0) (1.14.0)
# Requirement already satisfied: colorama in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from pandas->datasets) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: rich>=12.3.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from typer->transformers) (14.3.3)
# Requirement already satisfied: click>=8.2.1 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from typer->transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.23.0)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (5.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from rich>=12.3.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate>=1.1.0) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from jinja2->torch>=2.0.0->accelerate>=1.1.0) (3.0.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\tevin\onedrive\desktop\cfpb-complaint-intelligence\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Import Hugging Face dataset utility
from datasets import Dataset

# %%
# Import tokenizer, model, trainer, and training arguments
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    TrainingArguments,
    Trainer
)

# %% [markdown]
# #### Prepare BERT dataframe

# %%
# Create label mapping from grouped target
label2id = {label: i for i, label in enumerate(sorted(df_train["target_grouped"].unique()))}
id2label = {i: label for label, i in label2id.items()}

# %%
label2id
# Out:
# {'Auto loan': 0,
#  'Bank account': 1,
#  'Credit card': 2,
#  'Credit reporting': 3,
#  'Debt collection': 4,
#  'Money transfer': 5,
#  'Mortgage': 6,
#  'Other': 7,
#  'Personal loan': 8,
#  'Student loan': 9}

# %%
id2label
# Out:
# {0: 'Auto loan',
#  1: 'Bank account',
#  2: 'Credit card',
#  3: 'Credit reporting',
#  4: 'Debt collection',
#  5: 'Money transfer',
#  6: 'Mortgage',
#  7: 'Other',
#  8: 'Personal loan',
#  9: 'Student loan'}

# %%
# Create BERT-ready dataframe
df_bert = df_train[["text_clean", "target_grouped"]].copy()
df_bert["label"] = df_bert["target_grouped"].map(label2id)

# %%
df_bert
# Out:
#                                                text_clean    target_grouped  \
# 0       hi i am submitting this xxxx xxxx this isn t a...  Credit reporting
# 1       a federal education loan was fraudulently open...   Debt collection
# 2       i am writing to have the following information...  Credit reporting
# 3       i want this late payment remove from my accoun...       Credit card
# 4       i am disputing several items on my experian cr...  Credit reporting
# ...                                                   ...               ...
# 499995  xxxx should not be reporting to xxxx xxxx and ...  Credit reporting
# 499996  the credit bureaus are reporting inaccurate ou...  Credit reporting
# 499997  we receive at least 3 calls an hour all day lo...   Debt collection
# 499998  these can be combined on my credit report you ...  Credit reporting
# 499999  i am a victim of identity theft fraudulent har...  Credit reporting
#
#         label
# 0           3
# 1           4
# 2           3
# 3           2
# 4           3
# ...       ...
# 499995      3
# 499996      3
# 499997      4
# 499998      3
# 499999      3
#
# [500000 rows x 3 columns]

# %% [markdown]
# #### Sample smaller subset for BERT

# %%
# Sample a smaller subset for BERT fine tuning
df_bert_sample = df_bert.sample(n=50000, random_state=42)

# %%
train_df, test_df = train_test_split(
    df_bert_sample,
    test_size=0.2,
    random_state=42,
    stratify=df_bert_sample["label"]
)

# %%
# Check BERT train and test shapes
print(train_df.shape, test_df.shape)
# Out:
# (40000, 3) (10000, 3)

# %% [markdown]
# #### Convert to Hugging Face datasets

# %%
# Convert pandas dataframes to Hugging Face datasets
train_dataset = Dataset.from_pandas(train_df[["text_clean", "label"]])
test_dataset = Dataset.from_pandas(test_df[["text_clean", "label"]])

# %% [markdown]
# #### Load Tokenizer

# %%
# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")

# %% [markdown]
# #### Tokenize text for BERT

# %%
# Tokenize the text for BERT
def tokenize_function(examples):
    return tokenizer(
        examples["text_clean"],
        padding="max_length",
        truncation=True,
        max_length=256
    )

# %%
# Apply tokenization
train_dataset = train_dataset.map(tokenize_function, batched=True)
test_dataset = test_dataset.map(tokenize_function, batched=True)
# Out:
# Map:   0%|          | 0/40000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/10000 [00:00<?, ? examples/s]

# %%
train_dataset
# Out:
# Dataset({
#     features: ['text_clean', 'label', '__index_level_0__', 'input_ids', 'token_type_ids', 'attention_mask'],
#     num_rows: 40000
# })

# %%
test_dataset
# Out:
# Dataset({
#     features: ['text_clean', 'label', '__index_level_0__', 'input_ids', 'token_type_ids', 'attention_mask'],
#     num_rows: 10000
# })

# %% [markdown]
# #### DistilBERT training

# %%
# Remove unused text columns and set dataset format for PyTorch
train_dataset = train_dataset.remove_columns(["text_clean", "__index_level_0__"])
test_dataset = test_dataset.remove_columns(["text_clean", "__index_level_0__"])

train_dataset.set_format("torch")
test_dataset.set_format("torch")

# %%
# Load DistilBERT model for sequence classification
model = AutoModelForSequenceClassification.from_pretrained(
    "distilbert-base-uncased",
    num_labels=len(label2id),
    id2label=id2label,
    label2id=label2id
)
# Out:
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
# DistilBertForSequenceClassification LOAD REPORT from: distilbert-base-uncased
# Key                     | Status     |
# ------------------------+------------+-
# vocab_layer_norm.weight | UNEXPECTED |
# vocab_projector.bias    | UNEXPECTED |
# vocab_transform.bias    | UNEXPECTED |
# vocab_transform.weight  | UNEXPECTED |
# vocab_layer_norm.bias   | UNEXPECTED |
# classifier.weight       | MISSING    |
# classifier.bias         | MISSING    |
# pre_classifier.bias     | MISSING    |
# pre_classifier.weight   | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.

# %%
# Create metric function for evaluation
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=1)
    
    accuracy = accuracy_score(labels, preds)
    weighted_f1 = f1_score(labels, preds, average="weighted", zero_division=0)
    macro_f1 = f1_score(labels, preds, average="macro", zero_division=0)
    
    return {
        "accuracy": accuracy,
        "weighted_f1": weighted_f1,
        "macro_f1": macro_f1
    }

# %%
# Define training arguments
training_args = TrainingArguments(
    output_dir="./bert_results",
    eval_strategy="epoch",
    save_strategy="epoch",
    logging_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=2,
    weight_decay=0.01,
    load_best_model_at_end=True,
    metric_for_best_model="weighted_f1",
    greater_is_better=True,
    save_total_limit=1,
    report_to="none"
)

# %%
# Create Trainer object
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=compute_metrics
)

# %%
# Create Trainer object again
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=compute_metrics
)

# %% [markdown]
# #### Train the model

# %%
# Train DistilBERT model
trainer.train()
# Out:
# c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
#     <div>
#
#       <progress value='4123' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 4123/10000 4:51:19 < 6:55:28, 0.24 it/s, Epoch 0.82/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>

# %%
# Generate predictions on the test dataset
predictions = trainer.predict(test_dataset)
# Out:
# c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)

# %%
# Convert logits to predicted class ids
y_pred_bert = np.argmax(predictions.predictions, axis=1)

# %%
# Extract true labels from the test dataset
y_true_bert = predictions.label_ids

# %%
# Convert numeric predictions back to label names
y_pred_bert_labels = [id2label[i] for i in y_pred_bert]
y_true_bert_labels = [id2label[i] for i in y_true_bert]

# %%
# Print classification report for DistilBERT
print(classification_report(y_true_bert_labels, y_pred_bert_labels, zero_division=0))
# Out:
#                   precision    recall  f1-score   support
#
#        Auto loan       0.60      0.58      0.59       127
#     Bank account       0.79      0.77      0.78       491
#      Credit card       0.76      0.74      0.75       608
# Credit reporting       0.93      0.96      0.94      6682
#  Debt collection       0.78      0.72      0.75      1121
#   Money transfer       0.83      0.78      0.80       300
#         Mortgage       0.87      0.82      0.85       380
#            Other       0.00      0.00      0.00        14
#    Personal loan       0.49      0.31      0.38       118
#     Student loan       0.79      0.81      0.80       159
#
#         accuracy                           0.88     10000
#        macro avg       0.68      0.65      0.66     10000
#     weighted avg       0.88      0.88      0.88     10000

# %%
# Calculate summary metrics for DistilBERT
bert_accuracy = accuracy_score(y_true_bert_labels, y_pred_bert_labels)
bert_weighted_f1 = f1_score(y_true_bert_labels, y_pred_bert_labels, average="weighted", zero_division=0)
bert_macro_f1 = f1_score(y_true_bert_labels, y_pred_bert_labels, average="macro", zero_division=0)

print("DistilBERT Accuracy:", bert_accuracy)
print("DistilBERT Weighted F1:", bert_weighted_f1)
print("DistilBERT Macro F1:", bert_macro_f1)
# Out:
# DistilBERT Accuracy: 0.8828
# DistilBERT Weighted F1: 0.8795751137812376
# DistilBERT Macro F1: 0.6646156920561618

# %%
# Save the fine-tuned DistilBERT model and tokenizer
trainer.save_model(r"../models/distilbert_complaint_classifier")
tokenizer.save_pretrained(r"../models/distilbert_complaint_classifier")
# Out:
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# ('../models/distilbert_complaint_classifier\\tokenizer_config.json',
#  '../models/distilbert_complaint_classifier\\tokenizer.json')

# %% [markdown]
# DistilBERT Result
#
# DistilBERT achieved strong overall performance with 0.88 accuracy, 0.88 weighted F1, and 0.66 macro F1. This made it competitive with the strongest classical baseline, TF-IDF with Logistic Regression.
#
# Interpretation
#
# The BERT-based model improved class balance slightly relative to the standard TF-IDF baseline, as reflected in macro F1, but it did not clearly surpass the simpler model in overall weighted performance. This suggests that the complaint narratives contain strong keyword-level signal that is already well captured by TF-IDF, while transformer fine-tuning offers a more semantically robust but more computationally expensive alternative.

# %%
# Safely remove columns only if they exist
cols_to_remove = [col for col in ["text_clean", "__index_level_0__"] if col in train_dataset.column_names]
train_dataset = train_dataset.remove_columns(cols_to_remove)
test_dataset = test_dataset.remove_columns(cols_to_remove)

# %% [markdown]
# #### New Bert Sample

# %%
# Sample 200k rows for BERT fine tuning
df_bert_sample = df_bert.sample(n=150000, random_state=42)

# %%
# Check sampled BERT dataframe shape
df_bert_sample.shape
# Out:
# (250000, 3)

# %%
# Create train and test split for BERT
train_df, test_df = train_test_split(
    df_bert_sample,
    test_size=0.2,
    random_state=42,
    stratify=df_bert_sample["label"]
)

# %%
# Check train and test shapes
print(train_df.shape, test_df.shape)
# Out:
# (200000, 3) (50000, 3)

# %%
# Check grouped label distribution in the training split
train_df["target_grouped"].value_counts()
# Out:
# target_grouped
# Credit reporting    133768
# Debt collection      21979
# Credit card          12284
# Bank account          9978
# Mortgage              7515
# Money transfer        6129
# Student loan          3193
# Auto loan             2578
# Personal loan         2314
# Other                  262
# Name: count, dtype: int64

# %%
# Check grouped label distribution in the test split
test_df["target_grouped"].value_counts()
# Out:
# target_grouped
# Credit reporting    33442
# Debt collection      5494
# Credit card          3071
# Bank account         2494
# Mortgage             1879
# Money transfer       1532
# Student loan          798
# Auto loan             645
# Personal loan         579
# Other                  66
# Name: count, dtype: int64

# %%
# Save the 200k BERT sample to processed data
#df_bert_sample.to_csv("data/processed/df_bert_sample_200k.csv", index=False)

# %% [markdown]
# #### Hugging face dataset

# %%
# Convert pandas dataframes to Hugging Face datasets
train_dataset = Dataset.from_pandas(train_df[["text_clean", "label"]])
test_dataset = Dataset.from_pandas(test_df[["text_clean", "label"]])

# %% [markdown]
# #### Tokenizer

# %%
# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")

# %%
# Tokenize the text for BERT
def tokenize_function(examples):
    return tokenizer(
        examples["text_clean"],
        padding="max_length",
        truncation=True,
        max_length=256
    )

# %%
# Apply tokenization
train_dataset = train_dataset.map(tokenize_function, batched=True)
test_dataset = test_dataset.map(tokenize_function, batched=True)
# Out:
# Map:   0%|          | 0/200000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/50000 [00:00<?, ? examples/s]

# %%
# Safely remove extra columns and set PyTorch format
cols_to_remove = [col for col in ["text_clean", "__index_level_0__"] if col in train_dataset.column_names]
train_dataset = train_dataset.remove_columns(cols_to_remove)
test_dataset = test_dataset.remove_columns(cols_to_remove)

train_dataset.set_format("torch")
test_dataset.set_format("torch")

# %% [markdown]
# BERT class weight/ train

# %%
# Import PyTorch and class weight utility
import torch
import torch.nn as nn
from sklearn.utils.class_weight import compute_class_weight

# %%
# Get unique label ids from the training split
class_ids = sorted(train_df["label"].unique())

# %%
class_ids
# Out:
# [np.int64(0),
#  np.int64(1),
#  np.int64(2),
#  np.int64(3),
#  np.int64(4),
#  np.int64(5),
#  np.int64(6),
#  np.int64(7),
#  np.int64(8),
#  np.int64(9)]

# %%
# Compute balanced class weights
class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.array(class_ids),
    y=train_df["label"].values
)

# %%
# Convert class weights to a PyTorch tensor
class_weights_tensor = torch.tensor(class_weights, dtype=torch.float)

# %%
# Check class weights
print(class_weights_tensor)
# Out:
# tensor([ 7.7580,  2.0044,  1.6281,  0.1495,  0.9100,  3.2632,  2.6613, 76.3359,
#          8.6430,  6.2637])

# %% [markdown]
# #### Load DistilBERT

# %%
# Load DistilBERT model for sequence classification
model = AutoModelForSequenceClassification.from_pretrained(
    "distilbert-base-uncased",
    num_labels=len(label2id),
    id2label=id2label,
    label2id=label2id
)
# Out:
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
# DistilBertForSequenceClassification LOAD REPORT from: distilbert-base-uncased
# Key                     | Status     |
# ------------------------+------------+-
# vocab_projector.bias    | UNEXPECTED |
# vocab_transform.weight  | UNEXPECTED |
# vocab_transform.bias    | UNEXPECTED |
# vocab_layer_norm.bias   | UNEXPECTED |
# vocab_layer_norm.weight | UNEXPECTED |
# classifier.bias         | MISSING    |
# classifier.weight       | MISSING    |
# pre_classifier.bias     | MISSING    |
# pre_classifier.weight   | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.

# %%
# Create a custom Trainer that uses weighted cross-entropy loss
class WeightedTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False, **kwargs):
        labels = inputs.get("labels")
        outputs = model(**inputs)
        logits = outputs.get("logits")
        
        loss_fct = nn.CrossEntropyLoss(weight=class_weights_tensor.to(model.device))
        loss = loss_fct(logits, labels)
        
        return (loss, outputs) if return_outputs else loss

# %% [markdown]
# > git push origin main:main
# error: RPC failed; HTTP 408 curl 22 The requested URL returned error: 408
# send-pack: unexpected disconnect while reading sideband packet
# fatal: the remote end hung up unexpectedly
# Everything up-to-date

# %%
# Create metric function for evaluation
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=1)
    
    accuracy = accuracy_score(labels, preds)
    weighted_f1 = f1_score(labels, preds, average="weighted", zero_division=0)
    macro_f1 = f1_score(labels, preds, average="macro", zero_division=0)
    
    return {
        "accuracy": accuracy,
        "weighted_f1": weighted_f1,
        "macro_f1": macro_f1
    }

# %%
# Define training arguments for weighted-loss DistilBERT
training_args = TrainingArguments(
    output_dir="./bert_results_weighted_250k",
    eval_strategy="epoch",
    save_strategy="epoch",
    logging_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=3,
    weight_decay=0.01,
    load_best_model_at_end=True,
    metric_for_best_model="weighted_f1",
    greater_is_better=True,
    save_total_limit=1,
    report_to="none"
)

# %% [markdown]
# #### Trainer

# %%
# Create weighted Trainer object
trainer = WeightedTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=compute_metrics
)

# %%
# Train weighted DistilBERT model
trainer.train()
# Out:
# c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
#     <div>
#
#       <progress value='3327' max='75000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 3327/75000 4:06:26 < 88:32:05, 0.22 it/s, Epoch 0.13/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[72], line 2
#       1 # Train weighted DistilBERT model
# ----> 2 trainer.train()
#
# File c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\transformers\trainer.py:1424, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1422 ctx = suppress_progress_bars() if args.push_to_hub else contextlib.nullcontext()
#    1423 with ctx:
# -> 1424     return inner_training_loop(
#    1425         args=args,
#    1426         resume_from_checkpoint=resume_from_checkpoint,
#    1427         trial=trial,
#    1428         ignore_keys_for_eval=ignore_keys_for_eval,
#    1429     )
#
# File c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\transformers\trainer.py:1506, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1504 for epoch in range(epochs_trained, num_train_epochs):
#    1505     self.control = self.callback_handler.on_epoch_begin(self.args, self.state, self.control)
# -> 1506     self._run_epoch(
#    1507         model=model,
#    1508         epoch=epoch,
#    1509         train_dataloader=train_dataloader,
#    1510         steps_in_epoch=steps_in_epoch,
#    1511         num_update_steps_per_epoch=num_update_steps_per_epoch,
#    1512         trial=trial,
#    1513         ignore_keys_for_eval=ignore_keys_for_eval,
#    1514         start_time=start_time,
#    1515         resume_from_checkpoint=resume_from_checkpoint,
#    1516         epochs_trained=epochs_trained,
#    1517         steps_trained_in_current_epoch=steps_trained_in_current_epoch,
#    1518     )
#    1519     if self.control.should_training_stop:
#    1520         break
#
# File c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\transformers\trainer.py:1734, in Trainer._run_epoch(self, model, epoch, train_dataloader, steps_in_epoch, num_update_steps_per_epoch, trial, ignore_keys_for_eval, start_time, resume_from_checkpoint, epochs_trained, steps_trained_in_current_epoch)
#    1732     sync_context = functools.partial(self.accelerator.no_sync, model=model)
#    1733 with sync_context():
# -> 1734     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    1736 if (
#    1737     self.args.logging_nan_inf_filter
#    1738     and not is_torch_xla_available()
#    1739     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    1740 ):
#    1741     # if loss is nan or inf simply add the average of previous logged losses
#    1742     self._tr_loss += self._tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\transformers\trainer.py:1906, in Trainer.training_step(self, model, inputs, num_items_in_batch)
#    1903     return loss_mb.reduce_mean().detach().to(self.args.device)
#    1905 with self.compute_loss_context_manager():
# -> 1906     loss = self.compute_loss(model, inputs, num_items_in_batch=num_items_in_batch)
#    1908 del inputs
#    1909 if (
#    1910     self.args.torch_empty_cache_steps is not None
#    1911     and self.state.global_step % self.args.torch_empty_cache_steps == 0
#    1912 ):
#
# Cell In[68], line 5, in WeightedTrainer.compute_loss(self, model, inputs, return_outputs, **kwargs)
#       3 def compute_loss(self, model, inputs, return_outputs=False, **kwargs):
#       4     labels = inputs.get("labels")
# ----> 5     outputs = model(**inputs)
#       6     logits = outputs.get("logits")
#       8     loss_fct = nn.CrossEntropyLoss(weight=class_weights_tensor.to(model.device))
#
# File c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\transformers\utils\generic.py:876, in can_return_tuple.<locals>.wrapper(self, *args, **kwargs)
#     874 if return_dict_passed is not None:
#     875     return_dict = return_dict_passed
# --> 876 output = func(self, *args, **kwargs)
#     877 if not return_dict and not isinstance(output, tuple):
#     878     output = output.to_tuple()
#
# File c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:588, in DistilBertForSequenceClassification.forward(self, input_ids, attention_mask, inputs_embeds, labels, position_ids, **kwargs)
#     571 @can_return_tuple
#     572 @auto_docstring
#     573 def forward(
#    (...)
#     580     **kwargs: Unpack[TransformersKwargs],
#     581 ) -> SequenceClassifierOutput | tuple[torch.Tensor, ...]:
#     582     r"""
#     583     labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#     584         Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#     585         config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#     586         `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#     587     """
# --> 588     distilbert_output = self.distilbert(
#     589         input_ids=input_ids,
#     590         attention_mask=attention_mask,
#     591         inputs_embeds=inputs_embeds,
#     592         position_ids=position_ids,
#     593         return_dict=True,
#     594         **kwargs,
#     595     )
#     596     hidden_state = distilbert_output[0]  # (bs, seq_len, dim)
#     597     pooled_output = hidden_state[:, 0]  # (bs, dim)
#
# File c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\transformers\utils\generic.py:952, in merge_with_config_defaults.<locals>.wrapper(self, *args, **kwargs)
#     950             output = func(self, *args, **kwargs)
#     951     else:
# --> 952         output = func(self, *args, **kwargs)
#     953 # Restore original config value
#     954 finally:
#     955     if is_causal is not None:
#
# File c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\transformers\utils\output_capturing.py:248, in capture_outputs.<locals>.wrapped_fn.<locals>.wrapper(self, *args, **kwargs)
#     246 # Run the forward
#     247 try:
# --> 248     outputs = func(self, *args, **kwargs)
#     249 # Reset the states
#     250 finally:
#     251     _active_collector.reset(output_token)
#
# File c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:421, in DistilBertModel.forward(self, input_ids, attention_mask, inputs_embeds, position_ids, **kwargs)
#     413 embeddings = self.embeddings(input_ids, inputs_embeds, position_ids)
#     415 attention_mask = create_bidirectional_mask(
#     416     config=self.config,
#     417     inputs_embeds=embeddings,
#     418     attention_mask=attention_mask,
#     419 )
# --> 421 return self.transformer(
#     422     hidden_states=embeddings,
#     423     attention_mask=attention_mask,
#     424     **kwargs,
#     425 )
#
# File c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:280, in Transformer.forward(self, hidden_states, attention_mask, **kwargs)
#     273 def forward(
#     274     self,
#     275     hidden_states: torch.Tensor,
#     276     attention_mask: torch.Tensor | None = None,
#     277     **kwargs: Unpack[TransformersKwargs],
#     278 ) -> BaseModelOutput:
#     279     for layer_module in self.layer:
# --> 280         hidden_states = layer_module(
#     281             hidden_states,
#     282             attention_mask,
#     283             **kwargs,
#     284         )
#     286     return BaseModelOutput(last_hidden_state=hidden_states)
#
# File c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\transformers\modeling_layers.py:93, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      90         logger.warning_once(message)
#      92     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 93 return super().__call__(*args, **kwargs)
#
# File c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:252, in TransformerBlock.forward(self, hidden_states, attention_mask, **kwargs)
#     245 def forward(
#     246     self,
#     247     hidden_states: torch.Tensor,
#    (...)
#     250 ) -> tuple[torch.Tensor, ...]:
#     251     # Self-Attention
# --> 252     attention_output, _ = self.attention(
#     253         hidden_states,
#     254         attention_mask=attention_mask,
#     255         **kwargs,
#     256     )
#     257     attention_output = self.sa_layer_norm(attention_output + hidden_states)
#     259     # Feed Forward Network
#
# File c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:195, in DistilBertSelfAttention.forward(self, hidden_states, attention_mask, **kwargs)
#     189 value_layer = self.v_lin(hidden_states).view(*hidden_shape).transpose(1, 2)
#     191 attention_interface: Callable = ALL_ATTENTION_FUNCTIONS.get_interface(
#     192     self.config._attn_implementation, eager_attention_forward
#     193 )
# --> 195 attn_output, attn_weights = attention_interface(
#     196     self,
#     197     query_layer,
#     198     key_layer,
#     199     value_layer,
#     200     attention_mask,
#     201     dropout=0.0 if not self.training else self.dropout.p,
#     202     scaling=self.scaling,
#     203     **kwargs,
#     204 )
#     205 attn_output = attn_output.reshape(*input_shape, -1).contiguous()
#     206 attn_output = self.out_lin(attn_output)
#
# File c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\transformers\integrations\sdpa_attention.py:92, in sdpa_attention_forward(module, query, key, value, attention_mask, dropout, scaling, is_causal, **kwargs)
#      88     if attention_mask is not None and attention_mask.dtype != torch.bool:
#      89         # Convert to boolean type, making sdpa to force call FlashAttentionScore to improve performance.
#      90         attention_mask = torch.logical_not(attention_mask.bool()).to(query.device)
# ---> 92 attn_output = torch.nn.functional.scaled_dot_product_attention(
#      93     query,
#      94     key,
#      95     value,
#      96     attn_mask=attention_mask,
#      97     dropout_p=dropout,
#      98     scale=scaling,
#      99     is_causal=is_causal,
#     100     **sdpa_kwargs,
#     101 )
#     102 attn_output = attn_output.transpose(1, 2).contiguous()
#     104 return attn_output, None
#
# KeyboardInterrupt:

# %%
# Generate predictions on the test dataset
predictions = trainer.predict(test_dataset)

# %%
# Convert logits to predicted class ids
y_pred_bert = np.argmax(predictions.predictions, axis=1)

# %%
# Extract true labels
y_true_bert = predictions.label_ids

# %%
# Convert numeric ids back to label names
y_pred_bert_labels = [id2label[i] for i in y_pred_bert]
y_true_bert_labels = [id2label[i] for i in y_true_bert]

# %%
# Print classification report
print(classification_report(y_true_bert_labels, y_pred_bert_labels, zero_division=0))

# %%
# Calculate summary metrics for weighted DistilBERT
bert_accuracy = accuracy_score(y_true_bert_labels, y_pred_bert_labels)
bert_weighted_f1 = f1_score(y_true_bert_labels, y_pred_bert_labels, average="weighted", zero_division=0)
bert_macro_f1 = f1_score(y_true_bert_labels, y_pred_bert_labels, average="macro", zero_division=0)

print("Weighted DistilBERT Accuracy:", bert_accuracy)
print("Weighted DistilBERT Weighted F1:", bert_weighted_f1)
print("Weighted DistilBERT Macro F1:", bert_macro_f1)
