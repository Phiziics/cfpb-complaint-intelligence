# %%
# Import core libraries
import pandas as pd
import numpy as np

# %%
# Import model loading utility
import joblib

# %%
# Import evaluation tools
from sklearn.metrics import classification_report, confusion_matrix

# %%
# Optional display settings
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", 200)

# %%
# Load saved TF-IDF vectorizer
vectorizer = joblib.load("../models/tfidf_vectorizer.joblib")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Load saved TF-IDF vectorizer
# ----> 2 vectorizer = joblib.load("../models/tfidf_vectorizer.joblib")
#
# File c:\Users\tevin\OneDrive\Desktop\cfpb-complaint-intelligence\venv\lib\site-packages\joblib\numpy_pickle.py:735, in load(filename, mmap_mode, ensure_native_byte_order)
#     733         obj = _unpickle(fobj, ensure_native_byte_order=ensure_native_byte_order)
#     734 else:
# --> 735     with open(filename, "rb") as f:
#     736         with _validate_fileobject_and_memmap(f, filename, mmap_mode) as (
#     737             fobj,
#     738             validated_mmap_mode,
#     739         ):
#     740             if isinstance(fobj, str):
#     741                 # if the returned file object is a string, this means we
#     742                 # try to load a pickle file generated with an version of
#     743                 # Joblib so we load it with joblib compatibility function.
#
# FileNotFoundError: [Errno 2] No such file or directory: '../models/tfidf_vectorizer.joblib'

# %%
# Load saved Logistic Regression model
model = joblib.load("../models/logistic_regression_model.joblib")

# %%
# Confirm model and vectorizer loaded
print(type(vectorizer))
print(type(model))
